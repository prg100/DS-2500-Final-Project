# %% [markdown]
# <center> <h2>Final Project Dataset Creation</h2></center>

# %%
import requests
import pandas as pd
import re
import time

# %%
df = pd.DataFrame(columns=["name", "steam_review_score", "steam_total_positive", "steam_total_negative",  "price_initial", 
                           "steam_genres", "steam_categories", "release_date", "short_description", "required_age", 
                           "developers"])

# %% [markdown]
# * The following are the keys from the JSON objects returned from our Steam get call that we will use and what they represent:
#     * 'name' : the name of the game (string)
#     * 'steam_review_score' : rating out of 10
#     * 'steam_total_positive' : count of total amount of reviews that are positive
#     * 'steam_total_negative' : count of total amount of reviews that are negative
#     * 'price_initial' : price of the game when it was first released (in cents)
#     * 'steam_genres' : array of objects representing descriptive "genres" of this game for classification. These genres can include: Action, Casual, Indie, Strategy, etc.
#     * 'steam_categories' : array of objects representing descriptive "categories" of this game for classification. These categories are Steam specific and can include: Single-player, Steam Achievements, Steam Cloud
#     * 'release_date' : the date of release for the game
#     * 'short_description': a short sentence describing the game, there is a character cap so the sentence might not be complete
#     * 'required_age' : the required player age as a guidline to play this game, default value is 0 and can take value such as: 14, 16, 18, etc.
#     * 'developers' : the name of the developer

# %%
#pull a JSON object that includes ALL games and their Steam ID from Steam platform for further data pulling
new_requests = requests.get("http://api.steampowered.com/ISteamApps/GetAppList/v0002/?key=3DCA25D37E6882591F5A4B62A3E2A1C3&format=json").json()
new_requests['applist']['apps']
# Out:
# [{'appid': 216938, 'name': 'Pieterw test app76 ( 216938 )'},
#  {'appid': 660010, 'name': 'test2'},
#  {'appid': 660130, 'name': 'test3'},
#  {'appid': 1118314, 'name': ''},
#  {'appid': 383660, 'name': 'Deluxe Upgrade for Shadowrun Chronicles'},
#  {'appid': 383670, 'name': 'That Old Time Religion'},
#  {'appid': 383680, 'name': 'Void & Meddler - Soundtrack'},
#  {'appid': 383690, 'name': 'Mu Complex'},
#  {'appid': 383700, 'name': 'Boneless Zombie'},
#  {'appid': 383710, 'name': 'Princess KAGUYA'},
#  {'appid': 383720, 'name': 'Swords & Crossbones: An Epic Pirate Story'},
#  {'appid': 383730, 'name': 'RPG Maker 2000'},
#  {'appid': 383740, 'name': 'Marble Age: Remastered'},
#  {'appid': 383750, 'name': 'Funk of Titans'},
#  {'appid': 383760, 'name': 'War Thunder - Defenders Advanced Pack'},
#  {'appid': 383780, 'name': 'Judgement'},
#  {'appid': 383790, 'name': 'The Ship: Remasted'},
#  {'appid': 383800, 'name': 'Close Order'},
#  {'appid': 383810, 'name': "Doomed'n Damned"},
#  {'appid': 383840, 'name': 'Nimbatus - The Space Drone Constructor'},
#  {'appid': 383850, 'name': 'Radio Runner'},
#  {'appid': 383860, 'name': 'Area-X - Extra Gallery'},
#  {'appid': 383870, 'name': 'Firewatch'},
#  {'appid': 383900, 'name': 'Football Manager 2016 In-Game Editor'},
#  {'appid': 383901,
#   'name': 'Football Manager 2016 Touch Mode - No Loan Restrictions'},
#  {'appid': 383902,
#   'name': 'Football Manager 2016 Touch Mode - No Transfer Windows'},
#  {'appid': 383903, 'name': 'Football Manager 2016 Touch Mode - No Sacking'},
#  {'appid': 383904,
#   'name': 'Football Manager 2016 Touch Mode - National Management'},
#  {'appid': 383905,
#   'name': 'Football Manager 2016 Touch Mode - Board-Override'},
#  {'appid': 383906,
#   'name': 'Football Manager 2016 Touch Mode - No Work Permits'},
#  {'appid': 383907, 'name': 'Football Manager 2016 Touch Mode - Son Generated'},
#  {'appid': 383908,
#   'name': 'Football Manager 2016 Touch Mode - All Players Interested'},
#  {'appid': 383909,
#   'name': 'Football Manager 2016 Touch Mode - Foreign Influx'},
#  {'appid': 383910,
#   'name': 'Football Manager 2016 Touch Mode - Unlimited Scouting'},
#  {'appid': 383911,
#   'name': 'Football Manager 2016 Touch Mode - Attribute Masking'},
#  {'appid': 383920, 'name': 'Grail to the Thief Demo'},
#  {'appid': 383930, 'name': 'Doorways: Holy Mountains of Flesh'},
#  {'appid': 383940, 'name': 'Steam Marines 2'},
#  {'appid': 383950, 'name': 'League of Mermaids'},
#  {'appid': 383960, 'name': 'Machina of the Planet Tree -Planet Ruler-'},
#  {'appid': 383980, 'name': 'Rivals of Aether'},
#  {'appid': 383990,
#   'name': 'Battle Fantasia -Revised Edition- Original Soundtrack'},
#  {'appid': 384000, 'name': 'Cross of the Dutchman'},
#  {'appid': 384010, 'name': 'Castles'},
#  {'appid': 384020, 'name': 'PAYDAY 2: Yakuza Character Pack'},
#  {'appid': 384021, 'name': 'PAYDAY 2: Gage Ninja Pack'},
#  {'appid': 384030, 'name': 'Florensia'},
#  {'appid': 384040, 'name': 'Impulse Revolution'},
#  {'appid': 384050, 'name': 'Chime Sharp Demo'},
#  {'appid': 384060, 'name': 'Devouring Stars - Soundtrack'},
#  {'appid': 383130, 'name': 'SanctuaryRPG: Black Edition - Piano Collection'},
#  {'appid': 383140, 'name': 'Glorkian Warrior OST & Supporter Pack'},
#  {'appid': 383150, 'name': 'Dead Island Definitive Edition'},
#  {'appid': 383180, 'name': 'Dead Island Riptide Definitive Edition'},
#  {'appid': 383190, 'name': 'SUMICO - The Numbers Game'},
#  {'appid': 383230, 'name': 'Dungeon Souls'},
#  {'appid': 383240, 'name': 'Angels That Kill - The Final Cut'},
#  {'appid': 383250, 'name': "Don'Yoku OST"},
#  {'appid': 383270, 'name': 'Hue'},
#  {'appid': 383320, 'name': 'Transcendence - Eternity Port Expansion'},
#  {'appid': 383330, 'name': 'Star Chronicles: Delta Quadrant'},
#  {'appid': 383370, 'name': 'Wind of Luck: Arena - Asian Admiral pack'},
#  {'appid': 383380, 'name': 'Cosmonautica - Soundtrack'},
#  {'appid': 383400, 'name': 'WAKFU - Steel Beak Pack'},
#  {'appid': 383410, 'name': 'Codename CURE Dedicated Server'},
#  {'appid': 383430, 'name': 'The Black Watchmen Demo'},
#  {'appid': 383450, 'name': 'Battle of Empires : 1914-1918 -  British Empire'},
#  {'appid': 383460, 'name': 'Sound of Drop - fall into poison -'},
#  {'appid': 383470, 'name': 'Sound of Drop - fall into poison - Demo'},
#  {'appid': 383510, 'name': 'Grand Designer Pro'},
#  {'appid': 383520, 'name': 'Lilly and Sasha: Guardian Angels'},
#  {'appid': 383530, 'name': 'Vortex'},
#  {'appid': 383540, 'name': 'Metro Warp'},
#  {'appid': 383560, 'name': 'Squarelands'},
#  {'appid': 383570, 'name': 'Streets of Fury EX Demo'},
#  {'appid': 383580, 'name': 'Flesh Eaters'},
#  {'appid': 383590, 'name': 'Expert Rifleman - Reloaded'},
#  {'appid': 383600, 'name': 'Sea of Stars - Soundtrack'},
#  {'appid': 383610, 'name': 'Yargis Space Melee - Soundtrack / Artwork'},
#  {'appid': 383620, 'name': 'Flight Unlimited Las Vegas'},
#  {'appid': 383630, 'name': 'SEEP Universe'},
#  {'appid': 382630, 'name': 'Austin High'},
#  {'appid': 382640, 'name': 'Cinema Six'},
#  {'appid': 382650, 'name': 'The Man From Orlando'},
#  {'appid': 382660, 'name': 'In The Shadow'},
#  {'appid': 382670, 'name': 'Loves Her Gun'},
#  {'appid': 382680, 'name': 'Men With Beards'},
#  {'appid': 382690, 'name': 'How We Got Away With It'},
#  {'appid': 382700, 'name': 'Feeding Mr. Baldwin'},
#  {'appid': 382710, 'name': 'Circle The Wagen'},
#  {'appid': 382720, 'name': 'One Couch at a Time'},
#  {'appid': 382730, 'name': 'Losing LeBron'},
#  {'appid': 382740, 'name': 'The Poisoning'},
#  {'appid': 382750, 'name': 'A Line in the Sand'},
#  {'appid': 382760, 'name': 'Mile High Horror Shorts'},
#  {'appid': 382770, 'name': 'The Golden Scallop'},
#  {'appid': 382780, 'name': 'Steve Chong Finds Out That Suicide is a Bad Idea'},
#  {'appid': 382790, 'name': 'Aya: Awakenings'},
#  {'appid': 382800, 'name': 'Daylight'},
#  {'appid': 382810, 'name': 'L-Phase Equalizer'},
#  {'appid': 382811, 'name': 'L-Phase Multiband'},
#  {'appid': 382820, 'name': 'SONAR Demo (2015)'},
#  {'appid': 382840, 'name': 'Boz Digital Labs - ProChannel Collection'},
#  {'appid': 382850, 'name': 'Piercing Blow'},
#  {'appid': 382880, 'name': 'Feudalism'},
#  {'appid': 382890, 'name': 'FINAL FANTASY V'},
#  {'appid': 382900, 'name': 'FINAL FANTASY VI'},
#  {'appid': 382910, 'name': 'Blood Bowl 2 - Wood Elves'},
#  {'appid': 382920, 'name': 'RETSNOM'},
#  {'appid': 382940, 'name': 'Hitman™\xa0Beta'},
#  {'appid': 382950, 'name': 'Kings of Kung Fu OST'},
#  {'appid': 382990, 'name': 'BrainBread 2 Mod Tools'},
#  {'appid': 383010, 'name': 'JamG'},
#  {'appid': 383020, 'name': 'a Family of Grave Diggers'},
#  {'appid': 383040,
#   'name': 'Company of Heroes 2 - Soviet Skin: (H) Three Color Northwestern Front'},
#  {'appid': 383050, 'name': 'Yomi - Expansion Characters'},
#  {'appid': 383070, 'name': 'The Fleets of Sol'},
#  {'appid': 383080, 'name': 'Sakura Clicker'},
#  {'appid': 383100, 'name': 'Fragile Allegiance'},
#  {'appid': 383110, 'name': 'Battle Squadron'},
#  {'appid': 382250, 'name': 'Lightrise'},
#  {'appid': 382260, 'name': '8Bit Fiesta'},
#  {'appid': 382270, 'name': 'Space Xonix'},
#  {'appid': 382280, 'name': 'Abatron Dedicated Server'},
#  {'appid': 382300, 'name': 'Kidnapped'},
#  {'appid': 382320, 'name': 'Heart of Ember  '},
#  {'appid': 382330, 'name': 'Killers and Thieves'},
#  {'appid': 382350, 'name': "Devil's Bluff"},
#  {'appid': 382380, 'name': 'The Amber Throne'},
#  {'appid': 382390, 'name': 'Discouraged Workers - Digital Art Book'},
#  {'appid': 382400, 'name': 'Dungeons 2 - A Game of Winter'},
#  {'appid': 382410, 'name': 'Dungeons 2 - A Chance of Dragons'},
#  {'appid': 382420, 'name': 'E.T. Armies'},
#  {'appid': 382450, 'name': 'Tales Of Zestiria - Tales of Weapons'},
#  {'appid': 382451,
#   'name': 'Tales Of Zestiria -Tales of Characters Costume Set (Male)'},
#  {'appid': 382452,
#   'name': 'Tales Of Zestiria -Tales of Characters Costume Set (Female)'},
#  {'appid': 382460, 'name': 'Tales of Zestiria - Pre-order items'},
#  {'appid': 382461, 'name': 'Tales of Zestiria - Mystic Artes'},
#  {'appid': 382462, 'name': 'Tales of Zestiria - Adventure Items'},
#  {'appid': 382463, 'name': 'Tales of Zestiria - Free Skits Pack'},
#  {'appid': 382464, 'name': 'Tales of Zestiria - Seaside Resort Costumes Set'},
#  {'appid': 382465, 'name': 'Tales of Zestiria - God Eater free offer'},
#  {'appid': 382466, 'name': 'Tales of Zestiria - Attachments Set'},
#  {'appid': 382467, 'name': 'Tales of Zestiria - Evangelion Costume Set'},
#  {'appid': 382468, 'name': 'Tales of Zestiria - Idolmaster Costume Set'},
#  {'appid': 382469, 'name': 'Tales of Zestiria - School Costume Set'},
#  {'appid': 382470,
#   'name': "Tales of Zestiria - Additional Chapter: Alisha's Story"},
#  {'appid': 382480, 'name': 'Super Dungeon Run'},
#  {'appid': 382490, 'name': 'Relic Hunters Zero: Remix'},
#  {'appid': 382500, 'name': 'Yatagarasu Attack on Cataclysm Demo'},
#  {'appid': 382510,
#   'name': 'Yatagarasu Attack on Cataclysm Custom Voice Packs'},
#  {'appid': 382530, 'name': 'Supercharged Robot VULKAISER Demo'},
#  {'appid': 382620, 'name': 'Good Game'},
#  {'appid': 381770, 'name': 'Super Cyborg Demo'},
#  {'appid': 381780, 'name': '80 Days'},
#  {'appid': 381790, 'name': 'VRC PRO Deluxe Off-road tracks 2'},
#  {'appid': 381791, 'name': 'VRC PRO Deluxe Asia On-road tracks'},
#  {'appid': 381792, 'name': 'VRC PRO Professional Lifetime All-Inclusive'},
#  {'appid': 381800, 'name': 'DRIFT 84'},
#  {'appid': 381810, 'name': "Tom Clancy's EndWar Online"},
#  {'appid': 381830, 'name': 'Spectra - Soundtrack'},
#  {'appid': 381840, 'name': 'Trials Fusion - Awesome Level Max'},
#  {'appid': 381850, 'name': 'My Paper Boat'},
#  {'appid': 381870, 'name': 'Koala Kids'},
#  {'appid': 381880, 'name': "Red Rope: Don't Fall Behind"},
#  {'appid': 381890, 'name': 'Induction'},
#  {'appid': 381900, 'name': "Bard's Gold"},
#  {'appid': 381910, 'name': 'Xenocide'},
#  {'appid': 381940, 'name': 'Trials on Tatooine'},
#  {'appid': 381960, 'name': 'Fritz 14: Master Class Volume 1, Bobby Fischer'},
#  {'appid': 381970,
#   'name': 'Fritz for Fun 13: Master Class Volume 1, Bobby Fischer'},
#  {'appid': 381990, 'name': 'Dragon Saga'},
#  {'appid': 382000, 'name': 'Mindshow'},
#  {'appid': 382010, 'name': 'Yargis - Space Melee - Level Editor'},
#  {'appid': 382030, 'name': 'Yargis - Space Melee - Dedicated Server'},
#  {'appid': 382050, 'name': 'Eon Altar'},
#  {'appid': 382060, 'name': 'Scraps Demo & LAN Joiner'},
#  {'appid': 382070, 'name': 'Neoncube'},
#  {'appid': 382080, 'name': 'Action Alien'},
#  {'appid': 382090, 'name': 'Dungeon Nightmares II : The Memory'},
#  {'appid': 382110, 'name': 'Virtual Desktop'},
#  {'appid': 382120, 'name': 'Journey To The Center Of The Earth'},
#  {'appid': 382130, 'name': "Exile's End"},
#  {'appid': 382140, 'name': 'SKYHILL'},
#  {'appid': 382151, 'name': 'Badland Bandits - Ultimate'},
#  {'appid': 382160, 'name': 'Dark Years'},
#  {'appid': 382170, 'name': 'Always The Same Blue Sky... Original Soundtrack'},
#  {'appid': 382180, 'name': 'Devilry'},
#  {'appid': 382190, 'name': 'Sumo Revise OST'},
#  {'appid': 382200, 'name': 'Fantasy Grounds - D&D Princes of the Apocalypse'},
#  {'appid': 382210, 'name': 'Blood Bowl 2 - Lizardmen'},
#  {'appid': 382220,
#   'name': 'Sentinels of the Multiverse - Soundtrack (Volume 2)'},
#  {'appid': 381180, 'name': 'Edengrad'},
#  {'appid': 381191, 'name': 'Switch Galaxy Ultra Music Pack 1'},
#  {'appid': 381200, 'name': "Gary Grigsby's War in the East: Lost Battles"},
#  {'appid': 381201,
#   'name': "Gary Grigsby's War in the East: Don to the Danube"},
#  {'appid': 381210, 'name': 'Dead by Daylight'},
#  {'appid': 381220, 'name': 'Hydraulic Empire'},
#  {'appid': 381240, 'name': 'Farming Simulator 15 - New Holland Loader Pack'},
#  {'appid': 381250, 'name': 'Stardrift Nomads'},
#  {'appid': 381260, 'name': 'Orion Trail'},
#  {'appid': 381290, 'name': 'Dragon Rider'},
#  {'appid': 381310, 'name': 'Proton Pulse'},
#  {'appid': 381320, 'name': 'Bezier'},
#  {'appid': 381340, 'name': 'Mallow Drops'},
#  {'appid': 381550, 'name': 'The Arcslinger'},
#  {'appid': 381560, 'name': 'Epic Cards Battle(TCG)'},
#  {'appid': 381570, 'name': 'Dying Light Demo'},
#  {'appid': 381590, 'name': 'Shred! Downhill Mountain Biking'},
#  {'appid': 381600, 'name': 'MOAI: Build Your Dream Demo'},
#  {'appid': 381610,
#   'name': 'Dandy: Or a Brief Glimpse into the Life of the Candy Alchemist'},
#  {'appid': 381640, 'name': 'Allods Online RU'},
#  {'appid': 381650, 'name': 'Ashes of the Singularity - Soundtrack DLC'},
#  {'appid': 381670, 'name': 'WAKFU - Summer Pack'},
#  {'appid': 381671, 'name': 'WAKFU - Anathar Pack'},
#  {'appid': 381690, 'name': 'Reign Of Kings Dedicated Server'},
#  {'appid': 381710, 'name': 'Resident Evil 0 Costume Pack 1'},
#  {'appid': 381711, 'name': 'Resident Evil 0 Costume Pack 2'},
#  {'appid': 381712, 'name': 'Resident Evil 0 Costume Pack 3'},
#  {'appid': 381713, 'name': 'Resident Evil 0 Costume Pack 4'},
#  {'appid': 381715, 'name': 't-シャツ\u3000『週刊少年チャンピオン』コラボ'},
#  {'appid': 381717, 'name': 't-シャツ\u3000『GEO』コラボ'},
#  {'appid': 381720,
#   'name': "NOBUNAGA'S AMBITION: Tendou WPK - GAMECITYオンラインユーザー登録シリアル"},
#  {'appid': 381721,
#   'name': "NOBUNAGA'S AMBITION: Tendou WPK - my GAMECITY GCコインシリアル"},
#  {'appid': 381730,
#   'name': "NOBUNAGA'S AMBITION: Kakushin WPK - GAMECITYオンラインユーザー登録シリアル"},
#  {'appid': 381731,
#   'name': "NOBUNAGA'S AMBITION: Kakushin WPK - my GAMECITY GCコインシリアル"},
#  {'appid': 381750, 'name': 'RC Simulation 2.0'},
#  {'appid': 381760,
#   'name': 'Phantom Breaker: Battle Grounds - Kemomimi Costume DLC'},
#  {'appid': 380750, 'name': 'Anima Gate of Memories'},
#  {'appid': 380770, 'name': 'Wind of Luck: Arena'},
#  {'appid': 380800, 'name': 'Kholat: Original Soundtrack'},
#  {'appid': 380810, 'name': 'Herald: An Interactive Period Drama'},
#  {'appid': 380840, 'name': 'Teeworlds'},
#  {'appid': 380850, 'name': "ArcheAge: Explorer's  Pack"},
#  {'appid': 380860, 'name': 'Barbara-ian'},
#  {'appid': 380890,
#   'name': 'In Search of the Most Dangerous Town on the Internet'},
#  {'appid': 380900, 'name': 'Toukiden: Kiwami - Mission Collection 4-7'},
#  {'appid': 380901, 'name': 'Toukiden: Kiwami - Mission Collection 8-11'},
#  {'appid': 380910, 'name': 'D4: In Game Document Full Unlock Key'},
#  {'appid': 380920, 'name': 'Boss 101'},
#  {'appid': 380930, 'name': 'Train Valley Demo'},
#  {'appid': 380950, 'name': 'Bocce Revolution'},
#  {'appid': 380970, 'name': 'Car Mechanic Simulator 2015 Demo'},
#  {'appid': 380990, 'name': 'B.A.D Battle Armor Division'},
#  {'appid': 381000, 'name': '6 Nights'},
#  {'appid': 381010, 'name': 'Orion: A Sci-Fi Visual Novel'},
#  {'appid': 381020, 'name': 'Sky Rogue'},
#  {'appid': 381050, 'name': 'The Ritual on Weylyn Island'},
#  {'appid': 381090, 'name': 'Ted by Dawn'},
#  {'appid': 381100, 'name': 'The Men of Yoshiwara: Kikuya'},
#  {'appid': 381120, 'name': 'Shoppe Keep'},
#  {'appid': 381130, 'name': 'Karma'},
#  {'appid': 381140, 'name': 'Cruel Arena'},
#  {'appid': 381150, 'name': 'Counter-Strike Nexon: Zombies - Starter Pack'},
#  {'appid': 381151,
#   'name': 'Counter-Strike Nexon: Zombies - Journey to the West + Permanent Character'},
#  {'appid': 381152,
#   'name': 'Counter-Strike Nexon: Zombies - Dragon Set + Permanent Character'},
#  {'appid': 381160, 'name': 'DGU - Sinister Semester'},
#  {'appid': 381161, 'name': 'DGU - Midterm Mania'},
#  {'appid': 381162, 'name': 'DGU - Finals Week'},
#  {'appid': 381170, 'name': 'Lost in Paradise'},
#  {'appid': 380360, 'name': 'Tap Tap Infinity'},
#  {'appid': 380540, 'name': 'Inevitability'},
#  {'appid': 380550, 'name': 'Incandescent'},
#  {'appid': 380560, 'name': 'Spandex Force: Champion Rising'},
#  {'appid': 380570, 'name': 'Axion'},
#  {'appid': 380580, 'name': 'SpaceCorn'},
#  {'appid': 380610, 'name': "Galagan's Island: Reprymian Rising Demo"},
#  {'appid': 380640, 'name': 'Superstatic - Soundtrack'},
#  {'appid': 380650, 'name': 'HardLander'},
#  {'appid': 380660, 'name': 'Killing Time at Lightspeed: Enhanced Edition'},
#  {'appid': 380670, 'name': 'Final Approach'},
#  {'appid': 380680, 'name': 'Gwan Moon High School : The Ghost Gate'},
#  {'appid': 380690, 'name': "Don'Yoku"},
#  {'appid': 380700, 'name': 'Zombie Killtime'},
#  {'appid': 380710, 'name': 'Cradle - Soundtrack & Artbook'},
#  {'appid': 380720, 'name': 'Spandex Force: Champion Rising Demo'},
#  {'appid': 380740, 'name': 'TANE DLC: Nickel Plate High Speed Freight'},
#  {'appid': 379750, 'name': 'The Black Watchmen - Original Soundtrack'},
#  {'appid': 379760, 'name': 'Gravity Error'},
#  {'appid': 379800, 'name': 'Company of Heroes 2 Tools Data'},
#  {'appid': 379820, 'name': 'Son of Nor: Bible'},
#  {'appid': 379870, 'name': 'Alteil: Horizons'},
#  {'appid': 379960,
#   'name': 'Mahjong Pretty Girls Battle : School Girls Edition'},
#  {'appid': 379970, 'name': 'Tales of Cosmos Demo'},
#  {'appid': 379980, 'name': 'Panzermadels: Tank Dating Simulator'},
#  {'appid': 379990, 'name': 'Hush'},
#  {'appid': 380000, 'name': 'MiniOne Racing'},
#  {'appid': 380010, 'name': 'Tactical Genius Demo'},
#  {'appid': 380020, 'name': 'Three Heroes'},
#  {'appid': 380050, 'name': 'Crookz - The Big Heist Demo'},
#  {'appid': 380060, 'name': 'Xeno Galaxies - Workshop Edition Tool'},
#  {'appid': 380080, 'name': 'SONAR'},
#  {'appid': 380100, 'name': 'Flute Master'},
#  {'appid': 380120, 'name': "Celia's Quest"},
#  {'appid': 380130, 'name': 'Warhawks'},
#  {'appid': 380140, 'name': 'The Secret of Tremendous Corporation'},
#  {'appid': 380150, 'name': 'STASIS'},
#  {'appid': 380170, 'name': 'Highlands - Original Soundtrack'},
#  {'appid': 380210, 'name': 'Signal to Noise'},
#  {'appid': 380220, 'name': 'Hover Junkers'},
#  {'appid': 380230, 'name': 'Trove: Power Pack'},
#  {'appid': 380231, 'name': 'Trove - Arcanium Expedition Pack'},
#  {'appid': 380232, 'name': "Trove: Shadow's Eve Costume Pack"},
#  {'appid': 379553, 'name': 'FSX: Steam Edition - Albatros D.III (Oef) 253'},
#  {'appid': 379554, 'name': 'FSX: Steam Edition - FS Academy: On Instruments'},
#  {'appid': 379555, 'name': 'FSX: Steam Edition: Flight Tales II - Adrenaline'},
#  {'appid': 379556, 'name': 'FSX: Steam Edition - Grumman F11F-1 Tiger Add-On'},
#  {'appid': 379557,
#   'name': 'FSX: Steam Edition - Northrop F-5E Tiger II Add-On'},
#  {'appid': 379558, 'name': 'FSX: Steam Edition - REX Soft Clouds Add-On'},
#  {'appid': 379559,
#   'name': 'FSX: Steam Edition - Discover Australia and New Zealand'},
#  {'appid': 379560, 'name': 'FSX: Steam Edition - HD Airport Graphics Add-On'},
#  {'appid': 379561,
#   'name': 'FSX: Steam Edition - Natural Tree Environment X Add-On'},
#  {'appid': 379562,
#   'name': 'FSX: Steam Edition - World Environment 2012 Add-On'},
#  {'appid': 379563, 'name': 'FSX: Steam Edition - Diamond DA20-100 Katana 4X'},
#  {'appid': 379564, 'name': 'FSX: Steam Edition - Skychaser Add-On'},
#  {'appid': 379565, 'name': 'FSX: Steam Edition - FTX Trees HD Add-On'},
#  {'appid': 379566, 'name': 'FSX: Steam Edition - Embraer ERJ 145LR Add-On'},
#  {'appid': 379567,
#   'name': 'FSX: Steam Edition - Embraer ERJ 135LR &amp; 145XR Add-On'},
#  {'appid': 379568, 'name': 'FSX: Steam Edition - Piper Aztec Add-On'},
#  {'appid': 379570, 'name': 'FSX: Steam Edition - Extra 300S'},
#  {'appid': 379571, 'name': 'FSX: Steam Edition - DLC32'},
#  {'appid': 379572,
#   'name': 'FSX: Steam Edition - Twentynine Palms Airport Add-On'},
#  {'appid': 379575, 'name': 'FSX: Steam Edition - Embraer Phenom 100 Add-On'},
#  {'appid': 379576, 'name': 'FSX: Steam Edition - Rutan Q200 Add-On'},
#  {'appid': 379577,
#   'name': 'FSX: Steam Edition - Aerospool WT-9 Dynamic Add-On'},
#  {'appid': 379578, 'name': 'FSX: Steam Edition - Wittman Tailwind Add-On'},
#  {'appid': 379579, 'name': 'FSX: Steam Edition - VFR Czech Republic Add-On'},
#  {'appid': 379582, 'name': 'FSX: Steam Edition - ERCO Ercoupe 415C Add-On'},
#  {'appid': 379583, 'name': 'FSX: Steam Edition - Velocity XL RG Add-On'},
#  {'appid': 379584, 'name': 'FSX: Steam Edition - 737 Extreme Sound Add-On'},
#  {'appid': 379585, 'name': 'FSX: Steam Edition - Palo Alto Airport Add-On'},
#  {'appid': 379586,
#   'name': 'FSX: Steam Edition - Heraklion Airport (LGIR) Add-On'},
#  {'appid': 379587,
#   'name': 'FSX: Steam Edition - Kastellorizo Airport (LGKJ) Add-On'},
#  {'appid': 379589,
#   'name': 'FSX: Steam Edition - Night Environment Manager Add-On'},
#  {'appid': 379590, 'name': 'Toukiden: Kiwami - Mission Collection 1-3'},
#  {'appid': 379600, 'name': 'Diner Mania'},
#  {'appid': 379610, 'name': 'Animated Puzzles'},
#  {'appid': 379630, 'name': 'Penarium Demo'},
#  {'appid': 379640, 'name': 'Bloo Kid 2'},
#  {'appid': 379650, 'name': 'Cosmophony OST'},
#  {'appid': 379660, 'name': 'Cakewalk L-Phase Series Plug-ins'},
#  {'appid': 379670, 'name': 'Technolust'},
#  {'appid': 379680, 'name': 'Secrets of Grindea Translation Suite'},
#  {'appid': 379700,
#   'name': 'Automation - The Car Company Tycoon Game Workshop Tool'},
#  {'appid': 379720, 'name': 'DOOM'},
#  {'appid': 379730, 'name': 'RymdResa Soundtrack'},
#  {'appid': 379231, 'name': 'FSX: Steam Edition - Granville Gee Bee Model Z'},
#  {'appid': 379232, 'name': 'FSX: Steam Edition - Messerschmitt BF 109 Add-On'},
#  {'appid': 379233, 'name': 'FSX: Steam Edition - 3D Lights Redux Add-On'},
#  {'appid': 379234, 'name': 'FSX Orbx Asset Library'},
#  {'appid': 379235, 'name': 'FSX: Steam Edition - Friday Harbor (KFHR) Add-On'},
#  {'appid': 379240, 'name': 'FSX: Steam Edition - Republic RC-3 Seabee Add-On'},
#  {'appid': 379241, 'name': 'FSX: Steam Edition - Jabiru J160 Add-On'},
#  {'appid': 379242,
#   'name': 'FSX: Steam Edition - Grumman A-6E Intruder Add-On'},
#  {'appid': 379243,
#   'name': 'FSX: Steam Edition - Grumman EA-6B Prowler Add-On'},
#  {'appid': 379250, 'name': 'Lif Demo'},
#  {'appid': 379260, 'name': 'Atlantic Quest Solitaire'},
#  {'appid': 379270, 'name': 'Alarameth TD Demo'},
#  {'appid': 379280, 'name': 'SONAR - Legacy Plugins (32-Bit Only)'},
#  {'appid': 379290, 'name': 'Sumo Revise'},
#  {'appid': 379310, 'name': 'LISA the Joyful'},
#  {'appid': 379320, 'name': 'Clandestinity of Elsie'},
#  {'appid': 379340, 'name': 'Buggy'},
#  {'appid': 379350, 'name': 'Sol Divide'},
#  {'appid': 379370, 'name': 'Mobile Light Force'},
#  {'appid': 379380, 'name': 'ReLoaded'},
#  {'appid': 379390, 'name': 'Superstar Dance Club'},
#  {'appid': 379400, 'name': 'Crypt of the NecroDancer Extras'},
#  {'appid': 379420, 'name': 'Polynomial 2'},
#  {'appid': 379430, 'name': 'Kingdom Come: Deliverance'},
#  {'appid': 379520, 'name': 'DELTAZEAL'},
#  {'appid': 379530, 'name': 'Fate Tectonics'},
#  {'appid': 379541, 'name': 'FSX: Steam Edition - Greenland Nuuk Add-On'},
#  {'appid': 379542, 'name': 'FSX: Steam Edition - Rex 4 Texture Direct Add-On'},
#  {'appid': 379543, 'name': 'FSX: Steam Edition - Globe Swift GC1-A Add-On'},
#  {'appid': 379544, 'name': 'FSX: Steam Edition - Rutan 61 Long EZ Add-On'},
#  {'appid': 379545,
#   'name': 'FSX: Steam Edition - Grumman HU-16B Albatross Add-On'},
#  {'appid': 379546, 'name': 'FSX: Steam Edition - Accu-Feel'},
#  {'appid': 379547, 'name': 'FSX: Steam Edition - Lukla Airport (VNLK) Add-On'},
#  {'appid': 379548, 'name': 'FSX: Steam Edition - Meigs Field'},
#  {'appid': 379549,
#   'name': 'FSX: Steam Edition - Heinkel He219 Uhu (Owl) Add-On'},
#  {'appid': 379550, 'name': 'FSX: Steam Edition - Kilimanjaro Airport Add-On'},
#  {'appid': 379551, 'name': 'FSX: Steam Edition - FS Global 2010 Add-On'},
#  {'appid': 379552, 'name': 'FSX: Steam Edition - Paris Orly'},
#  {'appid': 378730, 'name': 'Race The Sun Original Soundtrack'},
#  {'appid': 378731, 'name': 'RTS - Sunrise'},
#  {'appid': 378750, 'name': 'Sayonara Umihara Kawase'},
#  {'appid': 378770, 'name': 'ESCHATOS'},
#  {'appid': 378790, 'name': '神楽道中記(KaguraDouchuuki)'},
#  {'appid': 378800, 'name': 'Police Tactics: Imperio'},
#  {'appid': 378810, 'name': 'Steamroll'},
#  {'appid': 378830, 'name': "The Princess' Heart"},
#  {'appid': 378850, 'name': "Galagan's Island: Reprymian Rising"},
#  {'appid': 378860, 'name': 'Project CARS 2'},
#  {'appid': 378890, 'name': 'Burnstar - Original Soundtrack'},
#  {'appid': 378910, 'name': 'Super Star Path Soundtrack'},
#  {'appid': 378950, 'name': 'Ori and the Blind Forest (Original Soundtrack)'},
#  {'appid': 379030, 'name': 'Sierra Ops Legacy (2015) Demo'},
#  {'appid': 379040, 'name': 'The Adventures of Tree Demo'},
#  {'appid': 379190, 'name': 'SAMURAI WARRIORS 4-II - Weapon Set'},
#  {'appid': 379191, 'name': 'SAMURAI WARRIORS 4-II - Exclusive Costume Set'},
#  {'appid': 379200, 'name': 'Undone: Project Nightmare Demo'},
#  {'appid': 379230, 'name': 'FSX: Steam Edition - Pushing the Envelope Add-On'},
#  {'appid': 378490, 'name': 'Sunny Hillride'},
#  {'appid': 378504, 'name': 'One Piece Pirate Warriors 3 DLC Pack 1'},
#  {'appid': 378505, 'name': 'One Piece Pirate Warriors 3 DLC Pack 2'},
#  {'appid': 378510, 'name': 'Witches, Heroes and Magic'},
#  {'appid': 378530, 'name': "Nature's Zombie Apocalypse"},
#  {'appid': 378540, 'name': 'The Surge'},
#  {'appid': 378550, 'name': "NASCAR '15 Paint Pack 1"},
#  {'appid': 378551, 'name': "NASCAR '15 Paint Pack 2"},
#  {'appid': 378552, 'name': "NASCAR '15 Paint Pack 3"},
#  {'appid': 378570, 'name': 'Robo Miner'},
#  {'appid': 378580, 'name': 'Untamed: Life Of A Cougar'},
#  {'appid': 378590, 'name': 'Forest Warrior'},
#  {'appid': 378610, 'name': 'Valley'},
#  {'appid': 378620, 'name': 'Chicken Invaders 3 - Christmas Edition'},
#  {'appid': 378621, 'name': 'Chicken Invaders 3 - Easter Edition'},
#  {'appid': 378630, 'name': 'Shadows on the Vatican - Act II: Wrath'},
#  {'appid': 378642,
#   'name': "The Witcher 3: Wild Hunt - New Quest 'Contract: Skellige's Most Wanted'"},
#  {'appid': 378643, 'name': 'The Witcher 3: Wild Hunt - Skellige Armor Set'},
#  {'appid': 378644,
#   'name': 'The Witcher 3: Wild Hunt - Alternative Look for Ciri'},
#  {'appid': 378645,
#   'name': "The Witcher 3: Wild Hunt - New Quest 'Where the Cat and Wolf Play...'"},
#  {'appid': 378646,
#   'name': 'The Witcher 3: Wild Hunt - New Finisher Animations'},
#  {'appid': 378647, 'name': 'The Witcher 3: Wild Hunt - NEW GAME +'},
#  {'appid': 378648, 'name': 'The Witcher 3: Wild Hunt - Blood and Wine'},
#  {'appid': 378649, 'name': 'The Witcher 3: Wild Hunt - Hearts of Stone '},
#  {'appid': 378650, 'name': 'Kyn Deluxe Edition'},
#  {'appid': 378660, 'name': 'Blues and Bullets'},
#  {'appid': 378670, 'name': 'Savage Lands Dedicated Server'},
#  {'appid': 378690, 'name': 'Potions: A Curious Tale'},
#  {'appid': 378700, 'name': 'Neptune Flux'},
#  {'appid': 378710, 'name': 'Viridi OST'},
#  {'appid': 378720, 'name': 'Thea: The Awakening'},
#  {'appid': 378040,
#   'name': 'Warhammer 40,000: Dawn of War II - Retribution - Ridiculously Bloody Blood Pack'},
#  {'appid': 378041,
#   'name': 'Warhammer 40,000: Dawn of War II - Retribution - The Last Stand Necron Overlord'},
#  {'appid': 378061, 'name': 'Vapour: Part 1 (Soundtrack)'},
#  {'appid': 378070, 'name': 'Energy Hook'},
#  {'appid': 378080, 'name': 'Rack N Ruin'},
#  {'appid': 378090, 'name': 'Rebel Wings'},
#  {'appid': 378100, 'name': 'Nyctophobia'},
#  {'appid': 378110, 'name': 'Hack RUN'},
#  {'appid': 378120, 'name': 'Football Manager 2016'},
#  {'appid': 378180, 'name': 'Football Manager 2016 Demo'},
#  {'appid': 378200, 'name': 'Football Manager 2016 Editor'},
#  {'appid': 378220, 'name': 'Football Manager 2016 Resource Archiver'},
#  {'appid': 378240, 'name': 'The Mors'},
#  {'appid': 378250, 'name': 'The Mors Demo'},
#  {'appid': 378260, 'name': 'Fortify'},
#  {'appid': 378270, 'name': 'Putrefaction'},
#  {'appid': 378280, 'name': 'Pump-Action Captain'},
#  {'appid': 378300, 'name': 'The Knobbly Crook'},
#  {'appid': 378330, 'name': 'Antisquad - DELUXE Upgrade'},
#  {'appid': 378350, 'name': 'Chromadrome 2'},
#  {'appid': 378360, 'name': 'Ymir'},
#  {'appid': 378370, 'name': 'Nomad'},
#  {'appid': 378380, 'name': 'Vapour: Part 1 (Demo)'},
#  {'appid': 378390, 'name': 'Production Inc.'},
#  {'appid': 378400, 'name': 'Gaokao.Love.100Days - Original Soundtrack'},
#  {'appid': 378410, 'name': 'Patchman vs. Red Circles'},
#  {'appid': 378420, 'name': 'Jurassic Island: The Dinosaur Zoo'},
#  {'appid': 378450, 'name': 'Robot Tsunami'},
#  {'appid': 378460, 'name': 'LOTUS-Simulator Module: Streets of LOTUS'},
#  {'appid': 378461, 'name': 'LOTUS-Simulator Module: Rails of LOTUS'},
#  {'appid': 378470, 'name': 'SAMURAI WARRIORS 4-II - Old Costumes Set'},
#  {'appid': 378471, 'name': 'SAMURAI WARRIORS 4-II - BGM Set 1'},
#  {'appid': 378472, 'name': 'SAMURAI WARRIORS 4-II - Edit Parts Set'},
#  {'appid': 378473, 'name': 'SAMURAI WARRIORS 4-II - Special Costume Set 1'},
#  {'appid': 378474, 'name': 'SAMURAI WARRIORS 4-II - Horse Set'},
#  {'appid': 378475, 'name': 'SAMURAI WARRIORS 4-II - Special Costume Set 2'},
#  {'appid': 378476, 'name': 'SAMURAI WARRIORS 4-II - BGM Set 2'},
#  {'appid': 378477, 'name': 'SAMURAI WARRIORS 4-II - Animal Set'},
#  {'appid': 378478, 'name': 'SAMURAI WARRIORS 4-II - Scenario Set'},
#  {'appid': 377500, 'name': 'Prismatica'},
#  {'appid': 377520, 'name': 'Pike and Shot: Campaigns'},
#  {'appid': 377530, 'name': '侠客风云传(Tale of Wuxia)'},
#  {'appid': 377540, 'name': 'Cast of the Seven Godsends - Soundtrack'},
#  {'appid': 377550, 'name': 'Unfair Jousting Fair'},
#  {'appid': 377560, 'name': 'Rainbow Six Siege - Ultra HD Texture Pack'},
#  {'appid': 377570, 'name': 'Space Drifters 2D'},
#  {'appid': 377590, 'name': 'IRFaceRig'},
#  {'appid': 377600, 'name': 'Tcheco in the Castle of Lucio'},
#  {'appid': 377640,
#   'name': 'Yearly Online Services Subscription for rFactor 2'},
#  {'appid': 377641, 'name': 'Lifetime Access to Online Services for rFactor 2'},
#  {'appid': 377660, 'name': 'Blockwick 2'},
#  {'appid': 377670, 'name': 'G-senjou no Maou - The Devil on G-String'},
#  {'appid': 377680, 'name': 'Sakura Beach'},
#  {'appid': 377690, 'name': 'Starlight Vega'},
#  {'appid': 377710, 'name': 'Idol Magical Girl Chiru Chiru Michiru Part 1'},
#  {'appid': 377720, 'name': 'Idol Magical Girl Chiru Chiru Michiru Part 2'},
#  {'appid': 377730, 'name': 'Shadowrun 5th Edition Rules pdf'},
#  {'appid': 377760, 'name': 'Fox & Flock'},
#  {'appid': 377770, 'name': 'Color Guardians Demo'},
#  {'appid': 377790, 'name': 'Toukiden: Kiwami - my GAMECITY GCコインシリアル'},
#  {'appid': 377840, 'name': 'FINAL FANTASY IX'},
#  {'appid': 377860, 'name': 'Mushihimesama'},
#  {'appid': 377870, 'name': 'DARIUSBURST Chronicle Saviours'},
#  {'appid': 377880, 'name': 'Eternal Destiny'},
#  {'appid': 377890, 'name': 'Blue Libra'},
#  {'appid': 377900, 'name': 'Empire TV Tycoon'},
#  {'appid': 377920,
#   'name': 'Warhammer 40,000: Eternal Crusade - Legendary Rogue Trader Points Pack'},
#  {'appid': 377930,
#   'name': 'Warhammer 40,000: Eternal Crusade - Epic Rogue Trader Points Pack'},
#  {'appid': 377940, 'name': 'Slam'},
#  {'appid': 377950, 'name': 'Jamestown+'},
#  {'appid': 377970, 'name': 'Void & Meddler'},
#  {'appid': 377980, 'name': 'Mortos'},
#  {'appid': 377990, 'name': 'kickplated'},
#  {'appid': 378030, 'name': 'Cardinal Quest 2'},
#  {'appid': 376990, 'name': 'Professor Teaches® Windows 10'},
#  {'appid': 377000, 'name': 'AnyTime® Organizer 15'},
#  {'appid': 377010, 'name': 'Easy Spanish™ Platinum'},
#  {'appid': 377020, 'name': 'The Magic Circle Demo'},
#  {'appid': 377030, 'name': 'Easy English™ Platinum'},
#  {'appid': 377040, 'name': 'Professor Teaches® Excel 2013 & 365'},
#  {'appid': 377050, 'name': 'Professor Teaches® Word 2013 & 365'},
#  {'appid': 377060, 'name': 'On a Roll'},
#  {'appid': 377070, 'name': 'Noctropolis'},
#  {'appid': 377080, 'name': 'Hatoful Boyfriend: Holiday Star'},
#  {'appid': 377100, 'name': 'UnderEarth'},
#  {'appid': 377120, 'name': 'Chronicle Keepers: The Dreaming Garden'},
#  {'appid': 377130, 'name': 'ValveTestApp377130'},
#  {'appid': 377140, 'name': 'Hide & Hold Out - H2o'},
#  {'appid': 377150, 'name': 'Tactical Genius'},
#  {'appid': 377160, 'name': 'Fallout 4'},
#  {'appid': 377170, 'name': 'TIMEframe Soundtrack'},
#  {'appid': 377190, 'name': 'Pale Echoes'},
#  {'appid': 377200, 'name': 'Daemon Detective Gaiden'},
#  {'appid': 377210, 'name': 'NiGHTMARE Zone'},
#  {'appid': 377220, 'name': 'Deficis'},
#  {'appid': 377250, 'name': 'Subaeria'},
#  {'appid': 377260, 'name': 'Unearned Bounty'},
#  {'appid': 377280, 'name': 'Alarameth TD'},
#  {'appid': 377290, 'name': 'Biodrone Battle'},
#  {'appid': 377310, 'name': 'The Tower Of Elements'},
#  {'appid': 377320, 'name': 'Hexters'},
#  {'appid': 377330, 'name': 'Close Your Eyes'},
#  {'appid': 377340, 'name': 'ChessBase 13 Academy'},
#  {'appid': 377350, 'name': 'ChessBase 13 Pro'},
#  {'appid': 377360, 'name': 'Western Press'},
#  {'appid': 377420, 'name': 'Close Your Eyes - Goodie Bag'},
#  {'appid': 377430, 'name': 'Who Is Mike'},
#  {'appid': 377440, 'name': 'Avalanche 2: Super Avalanche OST'},
#  {'appid': 377450, 'name': 'Lost Lands: Dark Overlord'},
#  {'appid': 377460, 'name': 'Chicken Invaders 3'},
#  {'appid': 377470, 'name': 'ENKI'},
#  {'appid': 377480, 'name': 'N.E.R.O.: Nothing Ever Remains Obscure'},
#  {'appid': 376931,
#   'name': 'Train Simulator: Amtrak® Dash 8-32BWH Loco Add-On '},
#  {'appid': 376932,
#   'name': 'Train Simulator: Feather River Canyon Route Add-On'},
#  {'appid': 376933, 'name': 'Train Simulator: Shanghai Maglev Route Add-On'},
#  {'appid': 376934, 'name': 'Train Simulator: Union Pacific DD35 Add-On'},
#  {'appid': 376935,
#   'name': 'Train Simulator: Outeniqua Choo Tjoe Route Add-On'},
#  {'appid': 376936,
#   'name': 'Train Simulator: Black Forest Journeys: Freiburg-Hausach Route Add-On'},
#  {'appid': 376938,
#   'name': 'Train Simulator: LGV: Marseille - Avignon Route Add-On'},
#  {'appid': 376939, 'name': 'TS Rewards - BR155 Press'},
#  {'appid': 376942, 'name': 'Train Simulator: USATC S160 Loco Add-On'},
#  {'appid': 376943, 'name': 'Train Simulator: Berlin - Leipzig Route Add-On'},
#  {'appid': 376944,
#   'name': 'Train Simulator: The Alaska Railroad: Anchorage - Seward Route Add-On'},
#  {'appid': 376945, 'name': 'Train Simulator: DB BR 648 Loco Add-On'},
#  {'appid': 376946, 'name': 'Train Simulator: Chatham Main Line Route Add-On'},
#  {'appid': 376947, 'name': 'Clear Creek ROW Livery Pack'},
#  {'appid': 376948, 'name': 'Clear Creek USA Livery Pack'},
#  {'appid': 376949, 'name': 'Train Simulator: ÖBB 1044 Loco Add-On'},
#  {'appid': 376950, 'name': 'Train Simulator: BR Blue Diesel Electric Pack'},
#  {'appid': 376951, 'name': 'Train Simulator: ÖBB 4023 ‘TALENT’ EMU Add-On'},
#  {'appid': 376952, 'name': 'Train Simulator: GWR Star Loco Add-On'},
#  {'appid': 376953,
#   'name': 'Train Simulator: Western Pacific FP7 ‘California Zephyr’ Loco Add-On'},
#  {'appid': 376954,
#   'name': 'Train Simulator: South West China High Speed Route Add-On'},
#  {'appid': 376955,
#   'name': 'Train Simulator: CRH 380A High Speed Train Add-On'},
#  {'appid': 376956,
#   'name': 'Train Simulator: DB BR 440 ‘Coradia Continental’ Loco Add-On'},
#  {'appid': 376957,
#   'name': 'TS Marketplace: Feather River Canyon Scenario Pack 01'},
#  {'appid': 376958, 'name': 'Train Simulator: Chessie System U30C Loco Add-On'},
#  {'appid': 376959, 'name': 'Train Simulator: Corris Railway Route Add-On'},
#  {'appid': 376960, 'name': 'Train Simulator: DB BR 112.1 Loco Add-On'},
#  {'appid': 376961,
#   'name': 'Train Simulator: Wakayama & Sakurai Lines Route Add-On'},
#  {'appid': 376962, 'name': 'Union Workshop Japan Signalling'},
#  {'appid': 376963,
#   'name': 'Train Simulator: GWR Saint Class & Travelling Post Office Loco Add-On'},
#  {'appid': 376964,
#   'name': 'TS Marketplace: North Jersey Coast Line Scenario Pack 01 Add-On'},
#  {'appid': 376965, 'name': 'Train Simulator: CSX C30-7 Loco Add-On'},
#  {'appid': 376966,
#   'name': 'Train Simulator: Albula Line: St Moritz - Thusis  Route Add-On'},
#  {'appid': 376967,
#   'name': 'TS Marketplace: New York New Haven Scenario Pack 01 Add-On'},
#  {'appid': 376968, 'name': 'TS Marketplace: CSX SD50 Livery Add-On'},
#  {'appid': 376969, 'name': 'Train Simulator: DB BR 18 Steam Loco Add-On'},
#  {'appid': 376970,
#   'name': 'Train Simulator: Wherry Lines: Norwich – Great Yarmouth & Lowestoft Route Add-On'},
#  {'appid': 376971, 'name': 'Train Simulator: Western Pacific GP35 Add-On'},
#  {'appid': 376972,
#   'name': 'Train Simulator: Clear Creek Log & Lumber Expansion Pack Add-On'},
#  {'appid': 376973, 'name': 'Train Simulator 2015 - DLC44'},
#  {'appid': 376974, 'name': 'Train Simulator 2015 - DLC45'},
#  {'appid': 376975, 'name': 'Train Simulator: Hamburg S1 S-Bahn Route Add-On'},
#  {'appid': 376976, 'name': 'Train Simulator: DB BR 10 Steam Loco Add-On'},
#  {'appid': 376977, 'name': 'Train Simulator: AT&SF SD45-2 Loco Add-On'},
#  {'appid': 376978, 'name': 'DB Schenker Class 67'},
#  {'appid': 376979,
#   'name': 'Train Simulator: Sacramento Northern: Suisun Bay – San Francisco Route Add-On'},
#  {'appid': 376980, 'name': 'Invisible, Inc. Contingency Plan'},
#  {'appid': 376520, 'name': 'Kelvin and the Infamous Machine'},
#  {'appid': 376530, 'name': 'Reboot Game Guides and Art Book'},
#  {'appid': 376540,
#   'name': 'Might & Magic Heroes VII: Beta additional - Uplay Activation'},
#  {'appid': 376550, 'name': 'Max Gentlemen - King Pack'},
#  {'appid': 376560, 'name': 'Big Fish Legend'},
#  {'appid': 376570, 'name': 'WildStar'},
#  {'appid': 376610,
#   'name': 'Toukiden: Kiwami - Armor - Sōma Outfit & Reki Outfit'},
#  {'appid': 376611, 'name': 'Toukiden: Kiwami - GAMECITYオンラインユーザー登録シリアル'},
#  {'appid': 376620, 'name': 'Arkin'},
#  {'appid': 376660, 'name': 'Hero Siege - Amazon (Class)'},
#  {'appid': 376670, 'name': 'Vortex Attack Demo'},
#  {'appid': 376680, 'name': 'Splendor'},
#  {'appid': 376700, 'name': 'The Escapists - Escape Team'},
#  {'appid': 376730, 'name': 'Monument'},
#  {'appid': 376750, 'name': 'World War II GI'},
#  {'appid': 376760, 'name': 'Big Thinkers Kindergarten'},
#  {'appid': 376770, 'name': 'Big Thinkers 1st Grade'},
#  {'appid': 376780,
#   'name': 'Sherlock Holmes Consulting Detective: The Case of the Tin Soldier'},
#  {'appid': 376790,
#   'name': 'Sherlock Holmes Consulting Detective: The Case of the Mystified Murderess'},
#  {'appid': 376800, 'name': 'Ginormasaurus - Hot Rod'},
#  {'appid': 376810, 'name': 'Guild of Dungeoneering Deluxe Edition'},
#  {'appid': 376820, 'name': 'Guild of Dungeoneering Soundtrack'},
#  {'appid': 376860, 'name': 'FleetCOMM - Original Soundtrack'},
#  {'appid': 376870, 'name': 'Minecraft: Story Mode - A Telltale Games Series'},
#  {'appid': 376880, 'name': 'ASTROKILL'},
#  {'appid': 376890, 'name': 'Pro Evolution Soccer 2016 Demo'},
#  {'appid': 376900, 'name': 'PES 2016 Digital Pre-order Pack'},
#  {'appid': 376901, 'name': 'PES 2016 Digital Exclusive Pack'},
#  {'appid': 376920, 'name': 'Tiki Man'},
#  {'appid': 376930, 'name': 'Train Simulator: ScotRail Class 68 Loco Add-on '},
#  {'appid': 376050, 'name': 'FINAL FANTASY XIV Online (NA)'},
#  {'appid': 376070, 'name': 'FINAL FANTASY XIV Online (JP)'},
#  {'appid': 376090, 'name': 'FINAL FANTASY XIV Online (PAL)'},
#  {'appid': 376110, 'name': 'Black Island'},
#  {'appid': 376120, 'name': 'Assault CorpsII'},
#  {'appid': 376130, 'name': 'Illuminascii'},
#  {'appid': 376140, 'name': 'SAGA'},
#  {'appid': 376150, 'name': 'Industry Transporters'},
#  {'appid': 376160, 'name': "DNO Rasa's Journey"},
#  {'appid': 376190, 'name': 'Enemy Demo'},
#  {'appid': 376200, 'name': '100% Orange Juice - Krila & Kae Character Pack'},
#  {'appid': 376230, 'name': 'Taimumari — Soundtrack'},
#  {'appid': 376240, 'name': 'Hadean Lands'},
#  {'appid': 376250, 'name': 'Ground Breakers'},
#  {'appid': 376280, 'name': 'Faceted Flight Demo'},
#  {'appid': 376300, 'name': 'GUILTY GEAR Xrd -SIGN-'},
#  {'appid': 376320, 'name': 'The Masterplan - Soundtrack'},
#  {'appid': 376350, 'name': 'OVERGRAVITY'},
#  {'appid': 376360, 'name': 'RaceRoom - WTCC 2014'},
#  {'appid': 376370, 'name': 'Awesomenauts - Gnariachi Skin'},
#  {'appid': 376371, 'name': 'Awesomenauts - Voltar Bonaparte Skin'},
#  {'appid': 376372, 'name': 'Awesomenauts - Shinobi Rocco Skin'},
#  {'appid': 376373, 'name': 'Awesomenauts - The Scrolls of XiPang Announcer'},
#  {'appid': 376390,
#   'name': "The Witcher 3: Wild Hunt - New Quest 'Fool's Gold'"},
#  {'appid': 376391,
#   'name': "The Witcher 3: Wild Hunt - 'Ballad Heroes' Neutral Gwent Card Set"},
#  {'appid': 376410, 'name': 'Acaratus'},
#  {'appid': 376450, 'name': 'Last Days of Old Earth'},
#  {'appid': 376480, 'name': 'Ohr'},
#  {'appid': 376490, 'name': 'The Great Gatsby: Secret Treasure'},
#  {'appid': 375520, 'name': 'Taimumari: Definitive Edition'},
#  {'appid': 375530, 'name': 'Football, Tactics & Glory'},
#  {'appid': 375550, 'name': 'DungeonRift'},
#  {'appid': 375560, 'name': 'DungeonRift Demo'},
#  {'appid': 375570, 'name': 'Goblin Quest: Escape!'},
#  {'appid': 375580, 'name': 'Three Days'},
#  {'appid': 375590, 'name': 'Epic Arena - Uniform Colors Pack'},
#  {'appid': 375610, 'name': 'Epic Arena - Spyglass'},
#  {'appid': 375620, 'name': 'CortexGear:AngryDroids'},
#  {'appid': 375630, 'name': 'Goblin Quest: Escape! - Soundtrack'},
#  {'appid': 375680, 'name': 'Apartment 666'},
#  {'appid': 375710, 'name': 'The Adventures of Mr. Bobley'},
#  {'appid': 375720, 'name': 'Tuk Ruk'},
#  {'appid': 375750, 'name': 'Invisigun Reloaded'},
#  {'appid': 375770, 'name': 'Quantum Conscience'},
#  {'appid': 375790, 'name': "Build 'n Bump"},
#  {'appid': 375800, 'name': 'Blasted Fortress Official Soundtrack'},
#  {'appid': 375810, 'name': 'The Forgettable Dungeon'},
#  {'appid': 375820, 'name': 'Human Resource Machine'},
#  {'appid': 375840, 'name': 'Rytmik Ultimate'},
#  {'appid': 375850, 'name': 'Island Defense'},
#  {'appid': 375860, 'name': '0RBITALIS - Supernova Edition Upgrade'},
#  {'appid': 375870, 'name': 'SLIDE: platformer'},
#  {'appid': 375880, 'name': 'Cast of the Seven Godsends Demo'},
#  {'appid': 375890, 'name': 'Football, Tactics & Glory Demo'},
#  {'appid': 375900, 'name': 'Trackmania Turbo'},
#  {'appid': 375910, 'name': 'Anno 2205'},
#  {'appid': 375930, 'name': 'Trap Them'},
#  {'appid': 375950, 'name': 'Viridi'},
#  {'appid': 375960, 'name': 'Pro Evolution Soccer 2016'},
#  {'appid': 375980, 'name': "AKIBA'S TRIP: Undead ＆ Undressed Demo"},
#  {'appid': 376010,
#   'name': 'FINAL FANTASY XIV: Heavensward - Standard Edition'},
#  {'appid': 376011,
#   'name': "FINAL FANTASY XIV: Heavensward - Collector's Edition"},
#  {'appid': 376020,
#   'name': 'FINAL FANTASY XIV: Heavensward - Pre-purchase Bonus Content'},
#  {'appid': 375020, 'name': "Al Emmo's Postcards from Anozira"},
#  {'appid': 375030, 'name': 'Korwin The Game'},
#  {'appid': 375040, 'name': 'Death Tractor'},
#  {'appid': 375090, 'name': 'The Eigengrau Menagerie'},
#  {'appid': 375120, 'name': 'Super Star Path'},
#  {'appid': 375130, 'name': 'Tin Star'},
#  {'appid': 375140, 'name': 'Tin Star Demo'},
#  {'appid': 375160, 'name': 'Discouraged Workers - Original Sound Track'},
#  {'appid': 375161, 'name': 'Discouraged Workers - Tarot PNP Pack'},
#  {'appid': 375170, 'name': 'Gunpowder'},
#  {'appid': 375180, 'name': 'Lunch Truck Tycoon'},
#  {'appid': 375190, 'name': 'VROOM: Aerie'},
#  {'appid': 375200, 'name': 'Sakura Fantasy Chapter 1'},
#  {'appid': 375210, 'name': 'Unveil'},
#  {'appid': 375220, 'name': 'Bitweb'},
#  {'appid': 375230, 'name': 'Warhammer 40,000: Eternal Crusade'},
#  {'appid': 375250, 'name': 'Pizza Express'},
#  {'appid': 375290, 'name': 'Superstatic'},
#  {'appid': 375310, 'name': 'Mighty Switch Force! Hose It Down!'},
#  {'appid': 375320, 'name': 'Colortone'},
#  {'appid': 375330, 'name': 'Butsbal'},
#  {'appid': 375340, 'name': 'Omni'},
#  {'appid': 375380, 'name': 'PAYDAY 2: Humble Mask Pack 3'},
#  {'appid': 375381, 'name': 'PAYDAY 2: Humble Mask Pack 4'},
#  {'appid': 375382, 'name': 'PAYDAY 2: The Jack Mask Pack'},
#  {'appid': 375383, 'name': 'PAYDAY 2: The Queen Mask Pack'},
#  {'appid': 375384, 'name': 'PAYDAY 2: The King Mask Pack'},
#  {'appid': 375385, 'name': 'PAYDAY 2: The Joker Mask Pack'},
#  {'appid': 375390, 'name': 'Anathema'},
#  {'appid': 375420, 'name': 'The Architect'},
#  {'appid': 375430, 'name': 'The Logomancer'},
#  {'appid': 375440, 'name': 'Hero-U: Rogue to Redemption'},
#  {'appid': 375450, 'name': "NOBUNAGA'S AMBITION: Souzou SengokuRisshiden"},
#  {'appid': 375460, 'name': '16bit Trader'},
#  {'appid': 375480, 'name': 'Chronicon'},
#  {'appid': 375500, 'name': 'The Deep Paths: Labyrinth Of Andokost'},
#  {'appid': 375510, 'name': 'New kind of adventure'},
#  {'appid': 374734, 'name': 'Blender: 6.6 Baking - Setting Up Material'},
#  {'appid': 374735, 'name': 'Blender: 6.7 Baking - Cord, Multiple UV Sets'},
#  {'appid': 374736, 'name': 'Blender: 6.8 Baking - Baking Camera Lens'},
#  {'appid': 374737, 'name': 'Blender: 7.1 3D Paint - Setup'},
#  {'appid': 374738, 'name': 'Blender: 7.2 3D Paint - Vertical Gradient'},
#  {'appid': 374739, 'name': 'Blender: 7.3 3D Paint - Multi Layered'},
#  {'appid': 374740,
#   'name': 'Blender: 7.4 3D Paint - Worn Edges, Cavity Masking'},
#  {'appid': 374741, 'name': 'Blender: 7.5 3D Paint - Baking All Layers To 1'},
#  {'appid': 374742, 'name': 'Blender: 8.1 Im/Export - Import TF2 Character'},
#  {'appid': 374743,
#   'name': 'Blender: 8.2 Im/Export - Rigging And Placing The Asset'},
#  {'appid': 374744, 'name': 'Blender: 8.3 Im/Export - LOD Creation'},
#  {'appid': 374745, 'name': 'Blender: 8.4 Im/Export - Exporting As OBJ'},
#  {'appid': 374746, 'name': 'Blender: 8.5 Im/Export - Importing Into TF2'},
#  {'appid': 374750, 'name': "ROOMS: The Toymaker's Mansion - Soundtrack"},
#  {'appid': 374770, 'name': 'LOTUS-Addon: Düsseldorf 1981'},
#  {'appid': 374780, 'name': 'Positron'},
#  {'appid': 374800, 'name': 'MotoGP™15: Moto2™ and Moto3™'},
#  {'appid': 374810, 'name': 'MotoGP™15: Season Pass'},
#  {'appid': 374820, 'name': 'Star Horizon - Soundtrack'},
#  {'appid': 374830, 'name': 'Defend The Highlands'},
#  {'appid': 374840, 'name': 'The Last Dogma - Soundtrack (FLAC & MP3)'},
#  {'appid': 374850, 'name': 'Farming Simulator 15 - New Holland Pack'},
#  {'appid': 374851, 'name': 'Farming Simulator 15 - Official Expansion (GOLD)'},
#  {'appid': 374871, 'name': 'LOTUS-Simulator: München Tram'},
#  {'appid': 374880, 'name': 'Tokyo School Life - Original Soundtrack '},
#  {'appid': 374890, 'name': 'Parcel Demo'},
#  {'appid': 374900, 'name': 'Agatha Christie - The ABC Murders'},
#  {'appid': 374930, 'name': 'Cash_Out Authoring Tools'},
#  {'appid': 374940, 'name': 'Tank Battle: Normandy'},
#  {'appid': 374950, 'name': 'ADventure Lib'},
#  {'appid': 374960, 'name': 'Civil War: Bull Run 1861'},
#  {'appid': 374970, 'name': 'Golf Masters'},
#  {'appid': 374990, 'name': 'Orc Slayer'},
#  {'appid': 375000, 'name': 'Icarus-X: Tides of Fire'},
#  {'appid': 375010, 'name': 'Energy Balance'},
#  {'appid': 374540, 'name': 'How to Take Off Your Mask Demo'},
#  {'appid': 374570, 'name': 'Kung Fury'},
#  {'appid': 374620, 'name': 'S.O.R.S'},
#  {'appid': 374630, 'name': 'Mactabilis'},
#  {'appid': 374640, 'name': 'March of Industry'},
#  {'appid': 374660, 'name': 'Waste Walkers Resource Toolkit DLC'},
#  {'appid': 374670, 'name': 'Ember Strike'},
#  {'appid': 374680, 'name': 'Tiki Galore'},
#  {'appid': 374690, 'name': 'RigIT'},
#  {'appid': 374700, 'name': 'Blender: 2.1 3D View - Menus, Modes and Display'},
#  {'appid': 374701,
#   'name': 'Blender: 2.2 3D View - Pivot Point, 3D Manipulator'},
#  {'appid': 374702, 'name': 'Blender: 2.3 3D View - Layers and Snapping'},
#  {'appid': 374703, 'name': 'Blender: 3.01 Modeling - Mesh and Object Data'},
#  {'appid': 374704, 'name': 'Blender: 3.02 Modeling - Object Tools'},
#  {'appid': 374705, 'name': 'Blender: 3.03 Modeling - Mesh - Extrude'},
#  {'appid': 374706, 'name': 'Blender: 3.04 Modeling - Mesh - Bevel'},
#  {'appid': 374707, 'name': 'Blender: 3.05 Modeling - Mesh - Subdivide'},
#  {'appid': 374708, 'name': 'Blender: 3.06 Modeling - Mesh - Loops'},
#  {'appid': 374709, 'name': 'Blender: 3.07 Modeling - Mesh - Vertex Connect'},
#  {'appid': 374710, 'name': 'Blender: 3.08 Modeling - Mesh - Inset'},
#  {'appid': 374711, 'name': 'Blender: 3.09 Modeling - Mesh - Merging'},
#  {'appid': 374712, 'name': 'Blender: 3.10 Modeling - Mesh - Knife'},
#  {'appid': 374713, 'name': 'Blender: 4.01 Assets - Ref Images, Blockout'},
#  {'appid': 374714, 'name': 'Blender: 4.02 Assets - Traffic Cone Modeling'},
#  {'appid': 374715,
#   'name': 'Blender: 4.03 Assets - Normals - Smooth/Hard Edges'},
#  {'appid': 374716, 'name': 'Blender: 4.04 Assets - High Res Traffic Cone'},
#  {'appid': 374717, 'name': 'Blender: 4.05 Assets - Camera Modeling'},
#  {'appid': 374718, 'name': 'Blender: 4.06 Assets - Modeling With Curves'},
#  {'appid': 374719, 'name': 'Blender: 4.07 Assets - Finishing Camera Model'},
#  {'appid': 374720, 'name': 'Blender: 4.08 Assets - Removing NGons'},
#  {'appid': 374721, 'name': 'Blender: 4.09 Assets - Lens And Ribbed Cable'},
#  {'appid': 374722, 'name': 'Blender: 4.10 Assets - Organizing Objects'},
#  {'appid': 374723, 'name': 'Blender: 5.1 UVs - Overview'},
#  {'appid': 374724, 'name': 'Blender: 5.2 UVs - Mirror Modifier'},
#  {'appid': 374725, 'name': 'Blender: 5.3 UVs - Unwrapping The Base'},
#  {'appid': 374726, 'name': 'Blender: 5.4 UVs - Unwrapping The Cable'},
#  {'appid': 374727, 'name': 'Blender: 5.5 UVs - Unwrapping The Cone'},
#  {'appid': 374728, 'name': 'Blender: 5.6 UVs - Final Layout'},
#  {'appid': 374729, 'name': 'Blender: 6.1 Baking - Setup and Images'},
#  {'appid': 374730, 'name': 'Blender: 6.2 Baking - Ambient Occlusion'},
#  {'appid': 374731, 'name': 'Blender: 6.3 Baking - Normal Maps'},
#  {'appid': 374732, 'name': 'Blender: 6.4 Baking - Creating Base Materials'},
#  {'appid': 374733, 'name': 'Blender: 6.5 Baking - Baking Base Color'},
#  {'appid': 374210, 'name': 'SBX: Invasion Demo'},
#  {'appid': 374220, 'name': 'new DREAMFLIGHT VR:For Oculus Rift Demo'},
#  {'appid': 374240, 'name': 'Eternal Step'},
#  {'appid': 374250, 'name': 'Catlateral Damage Official Soundtrack'},
#  {'appid': 374260, 'name': 'Retro Game Crunch Soundtrack'},
#  {'appid': 374300, 'name': 'PAYDAY 2: The Golden Grin Casino Heist'},
#  {'appid': 374301, 'name': 'PAYDAY 2: Sokol Character Pack'},
#  {'appid': 374320, 'name': 'DARK SOULS™ III'},
#  {'appid': 374360, 'name': 'Tembo The Badass Elephant Demo'},
#  {'appid': 374380, 'name': 'Revolution Under Siege Gold'},
#  {'appid': 374390, 'name': 'Call to Arms - Deluxe Edition'},
#  {'appid': 374400, 'name': 'VoiceBot'},
#  {'appid': 374410, 'name': 'TransPlan'},
#  {'appid': 374420, 'name': 'Questria: Rise of the Robot Skullfaces'},
#  {'appid': 374430, 'name': 'Freestyle 2 - Naughty Kitties Star Pack'},
#  {'appid': 374450, 'name': 'Cheats 4 Hire'},
#  {'appid': 374460, 'name': 'Impossiball'},
#  {'appid': 374500, 'name': 'Endless Legend - Shadows Expansion Pack'},
#  {'appid': 374510, 'name': 'The Last Dogma'},
#  {'appid': 374520, 'name': 'Champions of Anteria'},
#  {'appid': 374530, 'name': 'DiscStorm - Soundtrack'},
#  {'appid': 373720, 'name': 'Ryzom'},
#  {'appid': 373730, 'name': 'Way of Gold and Steel'},
#  {'appid': 373740, 'name': 'Pillars of Eternity - The White March - Part II'},
#  {'appid': 373750, 'name': 'DinoSystem'},
#  {'appid': 373770, 'name': 'LiEat'},
#  {'appid': 373780, 'name': 'Super Chibi Knight Original Sound Track (OST)'},
#  {'appid': 373800, 'name': 'Fantastic Pinball Thrills'},
#  {'appid': 373810, 'name': 'Hot Pinball Thrills'},
#  {'appid': 373820, 'name': 'Soccer Pinball Thrills'},
#  {'appid': 373860,
#   'name': 'Apothecarium: The Renaissance of Evil - Premium Edition'},
#  {'appid': 373870,
#   'name': 'Sister’s Secrecy: Arcanum Bloodlines - Premium Edition'},
#  {'appid': 373880, 'name': 'Fleeting Ages'},
#  {'appid': 373890, 'name': 'Web Designer 11 Premium'},
#  {'appid': 373910, 'name': 'Web Designer 11 Premium - Web Hosting (M)'},
#  {'appid': 373920, 'name': 'Eisenhorn: XENOS'},
#  {'appid': 373930, 'name': 'Sudden Strike 4'},
#  {'appid': 373940, 'name': 'Crusader Kings II: Orchestral House Lords'},
#  {'appid': 373950,
#   'name': 'The Witcher 3: Wild Hunt - Nilfgaardian Armor Set'},
#  {'appid': 373951, 'name': 'The Witcher 3: Wild Hunt - Elite Crossbow Set'},
#  {'appid': 373960, 'name': 'Audiosurf 2 Demo'},
#  {'appid': 373970, 'name': "Letter Quest: Grimm's Journey Remastered"},
#  {'appid': 373980, 'name': 'Galactic Civilizations III - Map Pack DLC'},
#  {'appid': 373990, 'name': 'Metrico+'},
#  {'appid': 374010,
#   'name': 'Sherlock Holmes Consulting Detective: The Case of the Mummy’s Curse'},
#  {'appid': 374030, 'name': 'Virginia'},
#  {'appid': 374040, 'name': 'Portal Knights'},
#  {'appid': 374050, 'name': 'Infinium Strike'},
#  {'appid': 374060, 'name': 'Stairs'},
#  {'appid': 374080, 'name': 'Falcon'},
#  {'appid': 374100, 'name': 'Unhack - Digital Artbook'},
#  {'appid': 374120, 'name': 'Forktuck Challenge'},
#  {'appid': 374130, 'name': 'Color Assembler Demo'},
#  {'appid': 374150, 'name': 'Concealed Intent'},
#  {'appid': 374160, 'name': 'Stones of Sorrow - Soundtrack by Neoandertals'},
#  {'appid': 374170, 'name': 'Sniper Tactical'},
#  {'appid': 374180, 'name': 'UFHO2 - Making Of & Extras'},
#  {'appid': 374190, 'name': 'Infernax'},
#  {'appid': 373250,
#   'name': 'Making History: The Calm and the Storm Gold Edition Demo'},
#  {'appid': 373280, 'name': 'Brutal Force'},
#  {'appid': 373290, 'name': 'Stones of Sorrow'},
#  {'appid': 373330, 'name': 'All Is Dust'},
#  {'appid': 373340, 'name': 'Pillars of Eternity - The White March - Part I'},
#  {'appid': 373350, 'name': 'Tobari and the Night of the Curious Moon Demo'},
#  {'appid': 373360, 'name': 'Cast of the Seven Godsends - Redux'},
#  {'appid': 373370, 'name': 'Europa Universalis IV: The Cossacks'},
#  {'appid': 373380, 'name': 'Europa Universalis IV: The Cossacks Content Pack'},
#  {'appid': 373390,
#   'name': 'Contradiction - the all-video murder mystery adventure'},
#  {'appid': 373400,
#   'name': 'Europa Universalis IV: Sounds from the community - Kairis Soundtrack'},
#  {'appid': 373420, 'name': 'Divinity: Original Sin Enhanced Edition'},
#  {'appid': 373440, 'name': 'Stargazer'},
#  {'appid': 373450, 'name': 'UFHO2 - Game Soundtrack'},
#  {'appid': 373460, 'name': 'Fury Of The Gods'},
#  {'appid': 373480, 'name': '1993 Space Machine'},
#  {'appid': 373490, 'name': "King's Quest - Chapter 4"},
#  {'appid': 373491, 'name': "King's Quest - Chapter 5"},
#  {'appid': 373560, 'name': 'D4: Special Costume Set -12 Beers-'},
#  {'appid': 373590, 'name': 'S.K.I.L.L. - Special Force 2 - Recruit Pack'},
#  {'appid': 373600, 'name': 'Weapon of Choice'},
#  {'appid': 373610, 'name': 'Shoot 1UP'},
#  {'appid': 373620, 'name': 'Explosionade'},
#  {'appid': 373630, 'name': 'Game Type'},
#  {'appid': 373640, 'name': 'Splotches'},
#  {'appid': 373650, 'name': 'The Assembly'},
#  {'appid': 373670, 'name': 'Arkhelom 3D'},
#  {'appid': 373680, 'name': 'Aion'},
#  {'appid': 373690, 'name': 'Cursed Sight - Digital artbook'},
#  {'appid': 373700, 'name': 'Lineage II'},
#  {'appid': 373711,
#   'name': 'Victory Command - Premium Account during Early Access'},
#  {'appid': 372890, 'name': 'Red Crow Mysteries: Legion'},
#  {'appid': 372900, 'name': 'Project CARS - Logitech Liveries'},
#  {'appid': 372910, 'name': 'Steam - Blacksheep'},
#  {'appid': 372920, 'name': 'DOMO - Summer is Here! (Male) DLC'},
#  {'appid': 372930, 'name': 'New York Mysteries: Secrets of the Mafia'},
#  {'appid': 372940, 'name': 'Lost Lands: The Four Horsemen'},
#  {'appid': 372950, 'name': 'Professor Why™: Chemistry 1'},
#  {'appid': 372960, 'name': 'Robbery Bob: Man of Steal'},
#  {'appid': 372970, 'name': 'Cash_Out'},
#  {'appid': 372980, 'name': 'MasterCook 15'},
#  {'appid': 373000, 'name': 'Family Tree Heritage'},
#  {'appid': 373020, 'name': 'Blender Game Asset Creation'},
#  {'appid': 373021, 'name': 'Blender: 1.2 UI Basics - Navigation'},
#  {'appid': 373022, 'name': 'Blender: 1.3 UI Basics - Layout Customization'},
#  {'appid': 373023, 'name': 'Blender: 1.4 UI Basics - User Preferences'},
#  {'appid': 373030, 'name': 'Dota 2 - Short Film Contest 2015'},
#  {'appid': 373080, 'name': 'Instinct'},
#  {'appid': 373090,
#   'name': 'Crimzon Clover WORLD IGNITION - Arcade Poster Pack'},
#  {'appid': 373120, 'name': 'Bernie Needs Love'},
#  {'appid': 373140, 'name': 'Grail to the Thief'},
#  {'appid': 373150, 'name': 'Europa Universalis IV: Common Sense Content Pack'},
#  {'appid': 373160, 'name': 'Europa Universalis IV: Common Sense E-Book'},
#  {'appid': 373170, 'name': 'Freestyle 2 -  Naughty Kitties Pro Pack'},
#  {'appid': 373171, 'name': 'Freestyle 2 - Naughty Kitties Rookie Pack'},
#  {'appid': 373180, 'name': 'Kung Fury: Street Rage'},
#  {'appid': 373190, 'name': 'The Epanalepsis Papers'},
#  {'appid': 373200, 'name': 'MotoGP™15: 4 Strokes Champions and Events'},
#  {'appid': 373220, 'name': 'Sunset OST'},
#  {'appid': 373240, 'name': 'Black Sails'},
#  {'appid': 372430, 'name': 'World Defense :  Fragmented Reality'},
#  {'appid': 372440, 'name': 'Koi-Koi Japan : Koi-Koi Enjoy Pack'},
#  {'appid': 372470, 'name': 'Batla - Toy Soldiers Pack'},
#  {'appid': 372480, 'name': 'Spaceforce Rogue Universe HD'},
#  {'appid': 372490, 'name': 'GROOVY'},
#  {'appid': 372500, 'name': 'Secrets of Grindea Demo'},
#  {'appid': 372510, 'name': 'D4: Mini Soundtrack'},
#  {'appid': 372511, 'name': 'D4: Special Art Book'},
#  {'appid': 372512, 'name': 'D4: Season One Voice Over Script'},
#  {'appid': 372520, 'name': 'Epanalepsis - Soundtrack'},
#  {'appid': 372540, 'name': 'The Lost Mythologies'},
#  {'appid': 372550, 'name': 'Siralim - Soundtrack'},
#  {'appid': 372560, 'name': 'Tanita: a plasticine dream'},
#  {'appid': 372570, 'name': 'A Stroke of Fate: Operation Bunker'},
#  {'appid': 372580, 'name': 'Lemma Demo'},
#  {'appid': 372590, 'name': 'Grand Designer'},
#  {'appid': 372630,
#   'name': 'Might & Magic Heroes VII: Beta - Uplay Activation'},
#  {'appid': 372650, 'name': 'Envelop for Windows'},
#  {'appid': 372660, 'name': 'Cursed Sight - Original Soundtrack'},
#  {'appid': 372670, 'name': 'Realm of Perpetual Guilds'},
#  {'appid': 372690, 'name': 'Chiptune Champion'},
#  {'appid': 372700, 'name': 'Realm of Perpetual Guilds Demo'},
#  {'appid': 372710, 'name': 'Game Character Hub: Second Story'},
#  {'appid': 372720, 'name': 'The Language Game'},
#  {'appid': 372730, 'name': "A Bastard's Tale Demo"},
#  {'appid': 372740, 'name': 'Second Warfare'},
#  {'appid': 372750, 'name': 'Girl Amazon Survival'},
#  {'appid': 372770, 'name': 'Floors of Discomfort'},
#  {'appid': 372780, 'name': 'Pulse'},
#  {'appid': 372800, 'name': 'RPG MO'},
#  {'appid': 372810, 'name': 'Echo Tokyo - Wallpapers'},
#  {'appid': 372820, 'name': 'Shot In The Dark'},
#  {'appid': 372830, 'name': 'Fitz the Fox'},
#  {'appid': 372860, 'name': 'Ramayana Demo'},
#  {'appid': 372870, 'name': 'Car Mechanic Simulator 2015 - Visual Tuning'},
#  {'appid': 372070, 'name': 'Alum Demo'},
#  {'appid': 372080, 'name': 'Ananias Roguelike'},
#  {'appid': 372100, 'name': 'Alum - Soundtrack'},
#  {'appid': 372110, 'name': 'Phantom Breaker: Battle Grounds - Frau Koujiro'},
#  {'appid': 372112,
#   'name': 'Phantom Breaker: Battle Grounds - FM sound generator BGM'},
#  {'appid': 372140, 'name': 'Labyrinthine Dreams - Soundtrack'},
#  {'appid': 372150, 'name': 'Yasai Ninja'},
#  {'appid': 372160, 'name': 'Soviet Monsters: Ekranoplans'},
#  {'appid': 372170, 'name': 'InsanZ - Dr.Test'},
#  {'appid': 372180, 'name': 'Locoland Demo'},
#  {'appid': 372190, 'name': 'Astro Lords: Oort Cloud'},
#  {'appid': 372200, 'name': 'Moonchild - Deluxe Contents'},
#  {'appid': 372210, 'name': 'Spooky Cats'},
#  {'appid': 372250, 'name': 'Turnover'},
#  {'appid': 372260, 'name': 'Weird Park Trilogy'},
#  {'appid': 372270, 'name': 'Millennium 5 - Deluxe Contents'},
#  {'appid': 372280, 'name': 'Asguaard - Deluxe Contents'},
#  {'appid': 372300, 'name': 'Premium Content - Soundtrack and Art Book'},
#  {'appid': 372301, 'name': 'Act 1 Soundtrack'},
#  {'appid': 372310, 'name': 'Act 2 Soundtrack'},
#  {'appid': 372320, 'name': 'LOST ORBIT: Terminal Velocity'},
#  {'appid': 372330, 'name': 'Beauty Bounce'},
#  {'appid': 372340, 'name': 'SnarfQuest Tales'},
#  {'appid': 372350, 'name': 'Tumbleweed Express'},
#  {'appid': 372360, 'name': 'Tales of Symphonia'},
#  {'appid': 372370, 'name': 'Brawlhalla - White Fang Gnash'},
#  {'appid': 372380, 'name': 'Warriors & Castles'},
#  {'appid': 372390, 'name': 'D3DGear - Game Recording and Streaming'},
#  {'appid': 372410, 'name': 'Dungeoncraft Demo'},
#  {'appid': 371740, 'name': 'DC Universe Online™ - Halls of Power Part II'},
#  {'appid': 371790, 'name': 'Ramayana'},
#  {'appid': 371800, 'name': 'Technobabylon Demo'},
#  {'appid': 371810, 'name': 'Dreaming'},
#  {'appid': 371840,
#   'name': 'Company of Heroes 2 - USF - Forward Assault Company '},
#  {'appid': 371841, 'name': 'Company of Heroes 2 - OKW - Firestorm Doctrine'},
#  {'appid': 371842,
#   'name': 'Company of Heroes 2 - USF - Tactical Support Company'},
#  {'appid': 371843, 'name': 'Company of Heroes 2 - British Alpha Faceplate'},
#  {'appid': 371844, 'name': 'Company of Heroes 2 - Panzergrau Bundle'},
#  {'appid': 371845, 'name': 'Company of Heroes 2 - OKW - Overwatch Doctrine'},
#  {'appid': 371846,
#   'name': 'Company of Heroes 2 - British Advanced Emplacement Regiment'},
#  {'appid': 371847,
#   'name': 'Company of Heroes 2 - British Mobile Assault Regiment'},
#  {'appid': 371848, 'name': 'Company of Heroes 2 - Warpaint Bundle Historic'},
#  {'appid': 371849, 'name': 'Company of Heroes 2 - Warpaint Bundle Fantasy'},
#  {'appid': 371850, 'name': 'Football Mogul 2014'},
#  {'appid': 371870, 'name': 'Act 3 Soundtrack'},
#  {'appid': 371880, 'name': 'Collider'},
#  ...]

# %%
#A sample request URL that provides a starting point for pulling game metadata
requestURL = 'https://store.steampowered.com/api/appdetails?appids=1121910'

# %%
#turn the referece list into a DataFrame object and save it to a csv file
reference_db = pd.DataFrame(new_requests['applist']['apps'])
reference_db.to_csv("reference_app_data.csv")

# %%
#add everything that is a success and has a type of 'game' to the database, spit out the error whenever one fail to add
#this took many trail and error to complete as every game sometimes have different key value missing
for item in new_requests['applist']['apps'][0:10000]:
  time.sleep(1.6);
  try:
    steamAppId = str(item['appid'])
    name = str(item['name'])
    requestURL = 'https://store.steampowered.com/api/appdetails?appids=' + steamAppId
    new_request = requests.get(requestURL).json()
    if new_request[steamAppId]['success'] == True:
      if 'type' in new_request[steamAppId]['data'].keys() and new_request[steamAppId]['data']['type'] == 'game':
        details = new_request[steamAppId]['data']
        required_age = details['required_age']            
        if details['is_free'] == True:
          price = '0'
        else:
          if 'price_overview' in details.keys() and 'initial' in details['price_overview'].keys():
            price = details['price_overview']['initial']
          else: 
            if len(details['package_groups']) > 1:
                price = details['package_groups'][0]['subs'][0]['price_in_cents_with_discount']
            else: price = ''

        #recommendations = details['recommendations']['total']

        steam_releasedate = details['release_date']['date']

        plat = [a for a in details['platforms'] if details['platforms'][a] == True]
        platform_available = ', '.join([str(i) for i in plat])

        steam_cat = [details['categories'][i]['description'] for i in range(len(details['categories']))]
        steam_categories = ', '.join([str(i) for i in steam_cat])

        steam_gen = [details['genres'][i]['description'] for i in range(len(details['genres']))]
        steam_genres = ', '.join([str(i) for i in steam_gen])

        devs = details['developers']
        steam_devs = ', '.join([str(i) for i in devs])

        short_description = details['short_description']

        # get review info
        try:
          requestURL = "https://store.steampowered.com/appreviews/" + steamAppId + "?json=1"
          response_reviews = requests.get(requestURL).json()
          summary = response_reviews["query_summary"]
          game_score_num = summary['review_score']
          total_positive = summary['total_positive']
          total_negative = summary['total_negative']
        except Exception as e:
          total_negative = ''
          total_positive = ''
          game_score_num = ''

        info = {"name": name, "steam_id" : steamAppId, "steam_review_score": game_score_num, 
                "steam_total_positive" : total_positive, "steam_total_negative": total_negative, 
                "price_initial": price, "steam_genres": steam_genres, "steam_categories": steam_categories, 
                "release_date": steam_releasedate, "short_description": short_description, "required_age" : required_age,
                "developers": steam_devs}
        df = df.append(info, ignore_index=True);
  except Exception as e2:
    print("Failed to add " + str(item['appid']))
    print(e2);
# Out:
# Failed to add 1081520
# 'categories'
# Failed to add 1081730
# 'categories'
# Failed to add 1080690
# 'developers'
# Failed to add 1079340
# 'categories'
# Failed to add 1079520
# 'categories'
# Failed to add 1077300
# 'categories'
# Failed to add 1075850
# 'categories'
# Failed to add 1075860
# 'categories'
# Failed to add 1074870
# 'categories'
# Failed to add 1074880
# 'categories'
# Failed to add 1074900
# 'categories'
# Failed to add 1074910
# 'categories'
# Failed to add 1074920
# 'categories'
# Failed to add 1074930
# 'categories'
# Failed to add 1073720
# 'categories'
# Failed to add 1074060
# 'categories'
# Failed to add 1073420
# 'categories'
# Failed to add 1071860
# 'categories'
# Failed to add 1071100
# 'categories'
# Failed to add 1070910
# 'categories'
# Failed to add 1068620
# 'categories'
# Failed to add 1066860
# 'categories'
# Failed to add 1065540
# 'categories'
# Failed to add 1063520
# 'categories'
# Failed to add 1062410
# 'categories'
# Failed to add 1061690
# 'categories'
# Failed to add 1058990
# 'categories'
# Failed to add 1136210
# 'categories'
# Failed to add 1133640
# 'categories'
# Failed to add 1132450
# 'categories'
# Failed to add 1127860
# 'categories'
# Failed to add 1127870
# 'categories'
# Failed to add 1127880
# 'categories'
# Failed to add 1126400
# 'categories'
# Failed to add 1125980
# 'categories'
# Failed to add 1126120
# 'categories'
# Failed to add 1123000
# 'categories'
# Failed to add 1121930
# 'categories'
# Failed to add 1118380
# 'categories'
# Failed to add 1027950
# 'categories'
# Failed to add 1027280
# 'categories'
# Failed to add 1026450
# 'categories'
# Failed to add 1025690
# 'categories'
# Failed to add 1025740
# 'developers'
# Failed to add 1025820
# 'categories'
# Failed to add 1025020
# 'categories'
# Failed to add 1024640
# 'categories'
# Failed to add 1023940
# 'categories'
# Failed to add 1023710
# 'categories'
# Failed to add 1023340
# 'categories'
# Failed to add 1021030
# 'categories'
# Failed to add 1019030
# 'genres'
# Failed to add 1018590
# 'categories'
# Failed to add 1017760
# 'developers'
# Failed to add 1017770
# 'developers'
# Failed to add 1017060
# 'categories'
# Failed to add 1016840
# 'categories'
# Failed to add 1012510
# 'categories'
# Failed to add 1010800
# 'categories'
# Failed to add 1011110
# 'categories'
# Failed to add 1009850
# 'categories'
# Failed to add 1009330
# 'categories'
# Failed to add 1008160
# 'categories'
# Failed to add 1008250
# 'categories'
# Failed to add 891420
# 'categories'
# Failed to add 889210
# 'genres'
# Failed to add 888370
# 'categories'
# Failed to add 888060
# 'categories'
# Failed to add 886420
# 'categories'
# Failed to add 885250
# 'categories'
# Failed to add 885440
# 'categories'
# Failed to add 884460
# 'categories'
# Failed to add 883290
# 'categories'
# Failed to add 882030
# 'categories'
# Failed to add 881680
# 'categories'
# Failed to add 881390
# 'categories'
# Failed to add 880310
# 'categories'
# Failed to add 878880
# 'categories'
# Failed to add 878890
# 'categories'
# Failed to add 877230
# 'developers'
# Failed to add 875460
# 'categories'
# Failed to add 873160
# 'genres'
# Failed to add 871810
# 'developers'
# Failed to add 871170
# 'categories'
# Failed to add 870820
# 'categories'
# Failed to add 913680
# 'categories'
# Failed to add 912870
# 'categories'
# Failed to add 912170
# 'categories'
# Failed to add 911840
# 'categories'
# Failed to add 911250
# 'categories'
# Failed to add 910050
# 'categories'
# Failed to add 910290
# 'developers'
# Failed to add 910370
# 'categories'
# Failed to add 910430
# 'developers'
# Failed to add 909460
# 'categories'
# Failed to add 908290
# 'categories'
# Failed to add 908520
# 'categories'
# Failed to add 907920
# 'developers'
# Failed to add 907180
# 'categories'
# Failed to add 906490
# 'categories'
# Failed to add 906390
# 'developers'
# Failed to add 904300
# 'genres'
# Failed to add 900883
# 'genres'
# Failed to add 899990
# 'genres'
# Failed to add 899150
# 'categories'
# Failed to add 898520
# 'categories'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-f32910426dbe> in <module>
#       3 import time
#       4 for item in new_requests['applist']['apps'][0:10000]:
# ----> 5   time.sleep(1.6);
#       6   try:
#       7     steamAppId = str(item['appid'])
#
# KeyboardInterrupt:

# %%
#df in this preview has empty fields as the initial idea was to include data from the game review website RAWG
#however due to time limitation and the complexity of RAWG API, we decided against it.
df
# Out:
#                             name steam_review_score steam_total_positive  \
# 0              Scallywag's Honor                  0                    0
# 1                 Disc Creatures                  8                   60
# 2                 符文女孩/Rune Girl                  5                   41
# 3                      PokeyPoke                  0                    0
# 4            Wingsuit: Gudvangen                  0                    0
# ...                          ...                ...                  ...
# 4380              Actionpaint VR                  0                    0
# 4381                   Exoplanet                  0                    0
# 4382          Bernie’s Nightmare                  5                   13
# 4383  Duke Dashington Remastered                  7                   17
# 4384                 Push Blox 2                  0                    7
#
#      steam_total_negative metacritic rawg_rating avg_playtime price_initial  \
# 0                       0        NaN         NaN          NaN
# 1                       4        NaN         NaN          NaN          1499
# 2                      21        NaN         NaN          NaN            99
# 3                       0        NaN         NaN          NaN
# 4                       2        NaN         NaN          NaN           799
# ...                   ...        ...         ...          ...           ...
# 4380                    0        NaN         NaN          NaN           599
# 4381                    0        NaN         NaN          NaN             0
# 4382                    6        NaN         NaN          NaN            99
# 4383                    0        NaN         NaN          NaN           499
# 4384                    0        NaN         NaN          NaN           199
#
#      rawg_genres rawg_tags                                       steam_genres  \
# 0            NaN       NaN  Action, Adventure, Indie, RPG, Simulation, Str...
# 1            NaN       NaN                      Adventure, Casual, Indie, RPG
# 2            NaN       NaN                      Adventure, Casual, Indie, RPG
# 3            NaN       NaN                                      Action, Indie
# 4            NaN       NaN                         Action, Simulation, Sports
# ...          ...       ...                                                ...
# 4380         NaN       NaN                          Casual, Indie, Simulation
# 4381         NaN       NaN  Adventure, Casual, Free to Play, Indie, RPG, S...
# 4382         NaN       NaN  Action, Adventure, Casual, Indie, Simulation, ...
# 4383         NaN       NaN                           Action, Adventure, Indie
# 4384         NaN       NaN                                              Indie
#
#                                        steam_categories total_recommendations  \
# 0        Single-player, Steam Achievements, Steam Cloud                   NaN
# 1             Single-player, Partial Controller Support                   NaN
# 2                            Single-player, Steam Cloud                   NaN
# 3                Single-player, Full controller support                   NaN
# 4     Single-player, Steam Achievements, Full contro...                   NaN
# ...                                                 ...                   ...
# 4380                                      Single-player                   NaN
# 4381                                      Single-player                   NaN
# 4382  Single-player, Steam Achievements, Captions av...                   NaN
# 4383  Single-player, Steam Achievements, Partial Con...                   NaN
# 4384                                      Single-player                   NaN
#
#          release_date                                  short_description  \
# 0         Coming soon  The Caribbean Sea, your sea, has been the home...
# 1        Oct 17, 2019  Humans live alongside creatures, each with dif...
# 2        Jun 28, 2019  This is a &quot;leisure&quot; game with a fine...
# 3     When it's done™                  Stab stuff and find shiny things.
# 4        Jun 25, 2019  Take to the skies in Wingsuit: Gudvangen and p...
# ...               ...                                                ...
# 4380     Sep 10, 2018              A fast and powerful paint experience.
# 4381     Jul 25, 2018  Create a crew and a ship to navigate a procedu...
# 4382     Jul 28, 2018  Nightmares come true in Bernie's Nightmare, a ...
# 4383     Nov 16, 2018  Hop into the shoes of Duke Dashington and save...
# 4384     May 27, 2020  Block-pushing puzzle game with challenging hig...
#
#      required_age esrb recommendation_score           developers steam_id
# 0               0  NaN                  NaN     Crazy Goat Games  1083150
# 1               0  NaN                  NaN       PICORINNE SOFT  1083190
# 2               0  NaN                  NaN                 ADOG  1083210
# 3               0  NaN                  NaN       Shaun Spalding  1083230
# 4               0  NaN                  NaN  Ninja Whale Studios  1083260
# ...           ...  ...                  ...                  ...      ...
# 4380            0  NaN                  NaN                  DNV   894360
# 4381            0  NaN                  NaN     Gregg Brzozowski   894380
# 4382            0  NaN                  NaN     Kevin Yang Games   894390
# 4383            0  NaN                  NaN    Adventure Islands   894420
# 4384            0  NaN                  NaN     Lonely Deckchair   894430
#
# [4385 rows x 20 columns]

# %%
#export the data
df.to_csv("data_finaltest.csv")
